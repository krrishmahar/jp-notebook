# %%
# %pip install "zenml[server]"
# !zenml integration install sklearn -y

import IPython
IPython.Application.instance().kernel.do_shutdown(restart=True)

# %% [markdown]
# ## ZenML setup

# %%
# !zenml init
# Out:
# Found existing ZenML repository at path 'C:\Users\Krrish\OneDrive -
# Padmabhushan Vasantdada Patil Pratishthan'S College Of
# Engineering\Desktop\jp-notebook\mlops'.
# Found existing ZenML repository at path 'C:\Users\Krrish\OneDrive -
# Padmabhushan Vasantdada Patil Pratishthan'S College Of
# Engineering\Desktop\jp-notebook\mlops'.
# +--------------------- Traceback (most recent call last) ---------------------+
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\z |
# | enml\cli\base.py:255 in init                                                |
# |                                                                             |
# |   252                                                                       |
# |   253     with console.status(f"Initializing ZenML repository at {path}.\n" |
# |   254         try:                                                          |
# | > 255             Client.initialize(root=path)                              |
# |   256             declare(f"ZenML repository initialized at {path}.")       |
# |   257         except InitializationException as e:                          |
# |   258             declare(f"{e}")                                           |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\z |
# | enml\client_lazy_loader.py:211 in _inner                                    |
# |                                                                             |
# |   208                     with contextlib.suppress(ValueError):             |
# |   209                         kwargs[k] = ClientLazyLoader(**v).evaluate()  |
# |   210                                                                       |
# | > 211             return func(*args_, **kwargs)                             |
# |   212                                                                       |
# |   213         return _inner                                                 |
# |   214                                                                       |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\z |
# | enml\client.py:514 in initialize                                            |
# |                                                                             |
# |    511         root = root or Path.cwd()                                    |
# |    512         logger.debug("Initializing new repository at path %s.", root |
# |    513         if Client.is_repository_directory(root):                     |
# | >  514             raise InitializationException(                           |
# |    515                 f"Found existing ZenML repository at path '{root}'." |
# |    516             )                                                        |
# |    517                                                                      |
# +-----------------------------------------------------------------------------+
# InitializationException: Found existing ZenML repository at path
# 'C:\Users\Krrish\OneDrive - Padmabhushan Vasantdada Patil Pratishthan'S College
# Of Engineering\Desktop\jp-notebook\mlops'.
#
# During handling of the above exception, another exception occurred:
#
# +--------------------- Traceback (most recent call last) ---------------------+
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\z |
# | enml\cli\base.py:258 in init                                                |
# |                                                                             |
# |   255             Client.initialize(root=path)                              |
# |   256             declare(f"ZenML repository initialized at {path}.")       |
# |   257         except InitializationException as e:                          |
# | > 258             declare(f"{e}")                                           |
# |   259             return                                                    |
# |   260                                                                       |
# |   261     declare(                                                          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\z |
# | enml\cli\utils.py:154 in declare                                            |
# |                                                                             |
# |    151     """                                                              |
# |    152     base_style = zenml_style_defaults["info"]                        |
# |    153     style = Style.chain(base_style, Style(bold=bold, italic=italic)) |
# | >  154     console.print(text, style=style, **kwargs)                       |
# |    155                                                                      |
# |    156                                                                      |
# |    157 def error(text: str) -> NoReturn:                                    |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:1678 in print                                                |
# |                                                                             |
# |   1675                 overflow = "ignore"                                  |
# |   1676             crop = False                                             |
# |   1677         render_hooks = self._render_hooks[:]                         |
# | > 1678         with self:                                                   |
# |   1679             renderables = self._collect_renderables(                 |
# |   1680                 objects,                                             |
# |   1681                 sep,                                                 |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:864 in __exit__                                              |
# |                                                                             |
# |    861                                                                      |
# |    862     def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any |
# |    863         """Exit buffer context."""                                   |
# | >  864         self._exit_buffer()                                          |
# |    865                                                                      |
# |    866     def begin_capture(self) -> None:                                 |
# |    867         """Begin capturing console output. Call :meth:`end_capture`  |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:822 in _exit_buffer                                          |
# |                                                                             |
# |    819     def _exit_buffer(self) -> None:                                  |
# |    820         """Leave buffer context, and render content if required."""  |
# |    821         self._buffer_index -= 1                                      |
# | >  822         self._check_buffer()                                         |
# |    823                                                                      |
# |    824     def set_live(self, live: "Live") -> None:                        |
# |    825         """Set Live instance. Used by Live context manager.          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:2019 in _check_buffer                                        |
# |                                                                             |
# |   2016             return                                                   |
# |   2017                                                                      |
# |   2018         try:                                                         |
# | > 2019             self._write_buffer()                                     |
# |   2020         except BrokenPipeError:                                      |
# |   2021             self.on_broken_pipe()                                    |
# |   2022                                                                      |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:2055 in _write_buffer                                        |
# |                                                                             |
# |   2052                             if self.no_color and self._color_system: |
# |   2053                                 buffer = list(Segment.remove_color(b |
# |   2054                                                                      |
# | > 2055                             legacy_windows_render(buffer, LegacyWind |
# |   2056                         else:                                        |
# |   2057                             # Either a non-std stream on legacy Wind |
# |   2058                             text = self._render_buffer(self._buffer[ |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\_windows_renderer.py:17 in legacy_windows_render                        |
# |                                                                             |
# |   14     for text, style, control in buffer:                                |
# |   15         if not control:                                                |
# |   16             if style:                                                  |
# | > 17                 term.write_styled(text, style)                         |
# |   18             else:                                                      |
# |   19                 term.write_text(text)                                  |
# |   20         else:                                                          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\_win32_console.py:441 in write_styled                                   |
# |                                                                             |
# |   438         SetConsoleTextAttribute(                                      |
# |   439             self._handle, attributes=ctypes.c_ushort(fore | (back <<  |
# |   440         )                                                             |
# | > 441         self.write_text(text)                                         |
# |   442         SetConsoleTextAttribute(self._handle, attributes=self._defaul |
# |   443                                                                       |
# |   444     def move_cursor_to(self, new_position: WindowsCoordinates) -> Non |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\_win32_console.py:402 in write_text                                     |
# |                                                                             |
# |   399         Args:                                                         |
# |   400             text (str): The text to write to the console              |
# |   401         """                                                           |
# | > 402         self.write(text)                                              |
# |   403         self.flush()                                                  |
# |   404                                                                       |
# |   405     def write_styled(self, text: str, style: Style) -> None:          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\encodings\cp125 |
# | 2.py:19 in encode                                                           |
# |                                                                             |
# |    16                                                                       |
# |    17 class IncrementalEncoder(codecs.IncrementalEncoder):                  |
# |    18     def encode(self, input, final=False):                             |
# | >  19         return codecs.charmap_encode(input,self.errors,encoding_table |
# |    20                                                                       |
# |    21 class IncrementalDecoder(codecs.IncrementalDecoder):                  |
# |    22     def decode(self, input, final=False):                             |
# +-----------------------------------------------------------------------------+
# UnicodeEncodeError: 'charmap' codec can't encode character '\u280b' in position
# 0: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# +--------------------- Traceback (most recent call last) ---------------------+
# | in _run_module_as_main:198                                                  |
# | in _run_code:88                                                             |
# |                                                                             |
# | in <module>:7                                                               |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\c |
# | lick\core.py:1130 in __call__                                               |
# |                                                                             |
# |   1127                                                                      |
# |   1128     def __call__(self, *args: t.Any, **kwargs: t.Any) -> t.Any:      |
# |   1129         """Alias for :meth:`main`."""                                |
# | > 1130         return self.main(*args, **kwargs)                            |
# |   1131                                                                      |
# |   1132                                                                      |
# |   1133 class Command(BaseCommand):                                          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\c |
# | lick\core.py:1055 in main                                                   |
# |                                                                             |
# |   1052         try:                                                         |
# |   1053             try:                                                     |
# |   1054                 with self.make_context(prog_name, args, **extra) as  |
# | > 1055                     rv = self.invoke(ctx)                            |
# |   1056                     if not standalone_mode:                          |
# |   1057                         return rv                                    |
# |   1058                     # it's not safe to `ctx.exit(rv)` here!          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\c |
# | lick\core.py:1657 in invoke                                                 |
# |                                                                             |
# |   1654                 super().invoke(ctx)                                  |
# |   1655                 sub_ctx = cmd.make_context(cmd_name, args, parent=ct |
# |   1656                 with sub_ctx:                                        |
# | > 1657                     return _process_result(sub_ctx.command.invoke(su |
# |   1658                                                                      |
# |   1659         # In chain mode we create the contexts step by step, but aft |
# |   1660         # base command has been invoked.  Because at that point we d |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\c |
# | lick\core.py:1404 in invoke                                                 |
# |                                                                             |
# |   1401             echo(style(message, fg="red"), err=True)                 |
# |   1402                                                                      |
# |   1403         if self.callback is not None:                                |
# | > 1404             return ctx.invoke(self.callback, **ctx.params)           |
# |   1405                                                                      |
# |   1406     def shell_complete(self, ctx: Context, incomplete: str) -> t.Lis |
# |   1407         """Return a list of completions for the incomplete value. Lo |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\c |
# | lick\core.py:760 in invoke                                                  |
# |                                                                             |
# |    757                                                                      |
# |    758         with augment_usage_errors(__self):                           |
# |    759             with ctx:                                                |
# | >  760                 return __callback(*args, **kwargs)                   |
# |    761                                                                      |
# |    762     def forward(                                                     |
# |    763         __self, __cmd: "Command", *args: t.Any, **kwargs: t.Any  # n |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\z |
# | enml\cli\base.py:253 in init                                                |
# |                                                                             |
# |   250             ) as worker:                                              |
# |   251                 worker.run_copy()                                     |
# |   252                                                                       |
# | > 253     with console.status(f"Initializing ZenML repository at {path}.\n" |
# |   254         try:                                                          |
# |   255             Client.initialize(root=path)                              |
# |   256             declare(f"ZenML repository initialized at {path}.")       |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\status.py:106 in __exit__                                               |
# |                                                                             |
# |   103         exc_val: Optional[BaseException],                             |
# |   104         exc_tb: Optional[TracebackType],                              |
# |   105     ) -> None:                                                        |
# | > 106         self.stop()                                                   |
# |   107                                                                       |
# |   108                                                                       |
# |   109 if __name__ == "__main__":  # pragma: no cover                        |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\status.py:91 in stop                                                    |
# |                                                                             |
# |    88                                                                       |
# |    89     def stop(self) -> None:                                           |
# |    90         """Stop the spinner animation."""                             |
# | >  91         self._live.stop()                                             |
# |    92                                                                       |
# |    93     def __rich__(self) -> RenderableType:                             |
# |    94         return self.renderable                                        |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\live.py:147 in stop                                                     |
# |                                                                             |
# |   144                 self._refresh_thread = None                           |
# |   145             # allow it to fully render on the last even if overflow   |
# |   146             self.vertical_overflow = "visible"                        |
# | > 147             with self.console:                                        |
# |   148                 try:                                                  |
# |   149                     if not self._alt_screen and not self.console.is_j |
# |   150                         self.refresh()                                |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:864 in __exit__                                              |
# |                                                                             |
# |    861                                                                      |
# |    862     def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any |
# |    863         """Exit buffer context."""                                   |
# | >  864         self._exit_buffer()                                          |
# |    865                                                                      |
# |    866     def begin_capture(self) -> None:                                 |
# |    867         """Begin capturing console output. Call :meth:`end_capture`  |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:822 in _exit_buffer                                          |
# |                                                                             |
# |    819     def _exit_buffer(self) -> None:                                  |
# |    820         """Leave buffer context, and render content if required."""  |
# |    821         self._buffer_index -= 1                                      |
# | >  822         self._check_buffer()                                         |
# |    823                                                                      |
# |    824     def set_live(self, live: "Live") -> None:                        |
# |    825         """Set Live instance. Used by Live context manager.          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:2019 in _check_buffer                                        |
# |                                                                             |
# |   2016             return                                                   |
# |   2017                                                                      |
# |   2018         try:                                                         |
# | > 2019             self._write_buffer()                                     |
# |   2020         except BrokenPipeError:                                      |
# |   2021             self.on_broken_pipe()                                    |
# |   2022                                                                      |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\console.py:2055 in _write_buffer                                        |
# |                                                                             |
# |   2052                             if self.no_color and self._color_system: |
# |   2053                                 buffer = list(Segment.remove_color(b |
# |   2054                                                                      |
# | > 2055                             legacy_windows_render(buffer, LegacyWind |
# |   2056                         else:                                        |
# |   2057                             # Either a non-std stream on legacy Wind |
# |   2058                             text = self._render_buffer(self._buffer[ |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\_windows_renderer.py:17 in legacy_windows_render                        |
# |                                                                             |
# |   14     for text, style, control in buffer:                                |
# |   15         if not control:                                                |
# |   16             if style:                                                  |
# | > 17                 term.write_styled(text, style)                         |
# |   18             else:                                                      |
# |   19                 term.write_text(text)                                  |
# |   20         else:                                                          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\_win32_console.py:441 in write_styled                                   |
# |                                                                             |
# |   438         SetConsoleTextAttribute(                                      |
# |   439             self._handle, attributes=ctypes.c_ushort(fore | (back <<  |
# |   440         )                                                             |
# | > 441         self.write_text(text)                                         |
# |   442         SetConsoleTextAttribute(self._handle, attributes=self._defaul |
# |   443                                                                       |
# |   444     def move_cursor_to(self, new_position: WindowsCoordinates) -> Non |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\site-packages\r |
# | ich\_win32_console.py:402 in write_text                                     |
# |                                                                             |
# |   399         Args:                                                         |
# |   400             text (str): The text to write to the console              |
# |   401         """                                                           |
# | > 402         self.write(text)                                              |
# |   403         self.flush()                                                  |
# |   404                                                                       |
# |   405     def write_styled(self, text: str, style: Style) -> None:          |
# |                                                                             |
# | C:\Users\Krrish\AppData\Local\Programs\Python\Python312\Lib\encodings\cp125 |
# | 2.py:19 in encode                                                           |
# |                                                                             |
# |    16                                                                       |
# |    17 class IncrementalEncoder(codecs.IncrementalEncoder):                  |
# |    18     def encode(self, input, final=False):                             |
# | >  19         return codecs.charmap_encode(input,self.errors,encoding_table |
# |    20                                                                       |
# |    21 class IncrementalDecoder(codecs.IncrementalDecoder):                  |
# |    22     def decode(self, input, final=False):                             |
# +-----------------------------------------------------------------------------+
# UnicodeEncodeError: 'charmap' codec can't encode character '\u280b' in position
# 0: character maps to <undefined>
